# %%
import os
from torchvision import datasets
import torchvision
import torch
from torchvision.transforms import transforms
import torchvision.models as models
import numpy as np
from PIL import ImageFile
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
ImageFile.LOAD_TRUNCATED_IMAGES = True
plt.ion()

# %%
batch_size = 5
num_workers = 0

transform = transforms.Compose([
    transforms.Resize(size=(256,256)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
train_set = 'E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Train'
valid_set = 'E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Test'

train_data = datasets.ImageFolder(train_set, transform=transform)
valid_data = datasets.ImageFolder(valid_set, transform=transform)

a = train_data.class_to_idx
print(a)
# print(a["Train"])

train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_data, batch_size=batch_size, num_workers=num_workers, shuffle=True)

loaders = {
    'train': train_loader,
    'valid': valid_loader
}
# Out:
# {'Fire': 0, 'Smoke': 1}

# %%
train_data
# Out:
# Dataset ImageFolder
#     Number of datapoints: 160
#     Root location: E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Train
#     StandardTransform
# Transform: Compose(
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=warn)
#                RandomResizedCrop(size=(224, 224), scale=(0.08, 1.0), ratio=(0.75, 1.3333), interpolation=bilinear, antialias=warn)
#                RandomHorizontalFlip(p=0.5)
#                RandomRotation(degrees=[-20.0, 20.0], interpolation=nearest, expand=False, fill=0)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %%
class_names = ['Fire', 'Neutral', 'Smoke']
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated

class_names = loaders["train"].dataset.classes
print(class_names)

# Get a batch of training data
inputs, classes = next(iter(train_loader))
print(inputs, classes)

# Make a grid from batch
out = torchvision.utils.make_grid(inputs)

imshow(out, title=[class_names[x] for x in classes])
# Out:
# ['Fire', 'Smoke']
# tensor([[[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#         [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#         [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#         [[[-2.1179, -2.1179, -2.1179,  ..., -0.6794, -0.7993, -2.1179],
#           [-1.9638, -1.9638, -1.9638,  ..., -0.6452, -0.7479, -2.1179],
#           [-1.9638, -1.9809, -1.9809,  ..., -0.5082, -0.6281, -2.1179],
#           ...,
#           [-2.1179, -1.8439, -1.7925,  ..., -0.5424, -0.6623, -0.6794],
#           [-2.1179, -1.5528, -1.5014,  ..., -0.5938, -0.6281, -0.6623],
#           [-2.1179, -0.9705, -0.9192,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ...,  0.2052,  0.1001, -2.0357],
#           [-1.7381, -1.7381, -1.7381,  ...,  0.1877,  0.1001, -2.0357],
#           [-1.7381, -1.7556, -1.7556,  ...,  0.2402,  0.1352, -2.0357],
#           ...,
#           [-2.0357, -1.6155, -1.6155,  ..., -0.4951, -0.5826, -0.5826],
#           [-2.0357, -1.3179, -1.3004,  ..., -0.5301, -0.5651, -0.5826],
#           [-2.0357, -0.7227, -0.7052,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ...,  0.5136,  0.4091, -1.8044],
#           [-1.4559, -1.4559, -1.4559,  ...,  0.4788,  0.3916, -1.8044],
#           [-1.4559, -1.4733, -1.4733,  ...,  0.5136,  0.4091, -1.8044],
#           ...,
#           [-1.8044, -1.3339, -1.3164,  ..., -0.6018, -0.6890, -0.7064],
#           [-1.8044, -1.0376, -1.0201,  ..., -0.6890, -0.7064, -0.7238],
#           [-1.8044, -0.4450, -0.4101,  ..., -1.8044, -1.8044, -1.8044]]],
#
#
#         [[[-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           ...,
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179],
#           [-2.1179, -2.1179, -2.1179,  ..., -2.1179, -2.1179, -2.1179]],
#
#          [[-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           ...,
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357],
#           [-2.0357, -2.0357, -2.0357,  ..., -2.0357, -2.0357, -2.0357]],
#
#          [[-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           ...,
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044],
#           [-1.8044, -1.8044, -1.8044,  ..., -1.8044, -1.8044, -1.8044]]]]) tensor([0, 1, 0, 1, 1])

# %%
model = models.resnet50(pretrained=True)


use_cuda = torch.cuda.is_available()

if use_cuda:
    model = model.cuda()
    
model
# Out:
# c:\Users\XYMA_HPC\anaconda3\envs\torch\lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\XYMA_HPC\anaconda3\envs\torch\lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=2048, out_features=1000, bias=True)
# )

# %%
for param in model.parameters():
    param.requires_grad = False

model.fc = torch.nn.Sequential(torch.nn.Linear(2048,128),
                                      torch.nn.ReLU(),
                                       torch.nn.Linear(128,3),
                                       torch.nn.Softmax()
                                      )

for param in model.fc.parameters():
    param.requires_grad = True
    
if use_cuda:
    model_transfer = model.cuda()
    
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (3): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (4): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (5): Bottleneck(
#       (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): Bottleneck(
#       (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (downsample): Sequential(
#         (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#     (2): Bottleneck(
#       (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Sequential(
#     (0): Linear(in_features=2048, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=128, out_features=3, bias=True)
#     (3): Softmax(dim=None)
#   )
# )

# %%
criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model_transfer.fc.parameters(), lr=0.0005)

# %%
n_epochs = 100

train_accuracy_list = []
train_loss_list = []
valid_accuracy_list = []
valid_loss_list = []

def train(n_epochs, loader, model, optimizer, criterion, use_cuda, save_path):
    
    valid_loss_min = np.Inf
       
    for epoch in range(1, (n_epochs+1)):
        
        train_loss = 0.0
        valid_loss = 0.0
        train_acc = 0.0
        valid_acc = 0.0
        
        model.train()
        
        for batch_idx, (data, target) in enumerate(loaders['train']):
            
            if use_cuda:
                data, target = data.cuda(), target.cuda()

            optimizer.zero_grad()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            loss.backward()
            optimizer.step()
            
            train_acc = train_acc + torch.sum(preds == target.data)
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.data - train_loss))
            
            model.eval()
        for batch_idx, (data, target) in enumerate(loaders['valid']):

            if use_cuda:
                data, target = data.cuda(), target.cuda()
            output = model(data)
            _, preds = torch.max(output, 1)
            loss = criterion(output, target)
            
            valid_acc = valid_acc + torch.sum(preds == target.data)
            valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.data - valid_loss))
            
        train_loss = train_loss/len(loaders['train'].dataset)
        valid_loss = valid_loss/len(loaders['valid'].dataset)
        train_acc = train_acc/len(loaders['train'].dataset)
        valid_acc = valid_acc/len(loaders['valid'].dataset)
        
        train_accuracy_list.append(train_acc)
        train_loss_list.append(train_loss)
        valid_accuracy_list.append(valid_acc)
        valid_loss_list.append(valid_loss)
        
        print('Epoch: {} \tTraining Acc: {:6f} \tTraining Loss: {:6f} \tValidation Acc: {:6f} \tValidation Loss: {:.6f}'.format(
            epoch,
            train_acc,
            train_loss,
            valid_acc,
            valid_loss
            ))

        if valid_loss <= valid_loss_min:
            print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
            valid_loss_min,
            valid_loss))
            torch.save(model.state_dict(), save_path)
            valid_loss_min = valid_loss  
            
    return model

# %%
model = train(n_epochs, loaders, model, optimizer, criterion, use_cuda, 'E:/Smoke/model_transfer.pt')
# Out:
# c:\Users\XYMA_HPC\anaconda3\envs\torch\lib\site-packages\torch\nn\modules\container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Epoch: 1 	Training Acc: 0.656250 	Training Loss: 0.005500 	Validation Acc: 0.950000 	Validation Loss: 0.032540
# Validation loss decreased (inf --> 0.032540).  Saving model ...
# Epoch: 2 	Training Acc: 0.875000 	Training Loss: 0.004431 	Validation Acc: 0.700000 	Validation Loss: 0.041896
# Epoch: 3 	Training Acc: 0.925000 	Training Loss: 0.004058 	Validation Acc: 1.000000 	Validation Loss: 0.030526
# Validation loss decreased (0.032540 --> 0.030526).  Saving model ...
# Epoch: 4 	Training Acc: 0.943750 	Training Loss: 0.003920 	Validation Acc: 0.750000 	Validation Loss: 0.038221
# Epoch: 5 	Training Acc: 0.950000 	Training Loss: 0.003901 	Validation Acc: 1.000000 	Validation Loss: 0.028107
# Validation loss decreased (0.030526 --> 0.028107).  Saving model ...
# Epoch: 6 	Training Acc: 0.943750 	Training Loss: 0.003856 	Validation Acc: 0.900000 	Validation Loss: 0.031810
# Epoch: 7 	Training Acc: 0.931250 	Training Loss: 0.003905 	Validation Acc: 1.000000 	Validation Loss: 0.029404
# Epoch: 8 	Training Acc: 0.943750 	Training Loss: 0.003856 	Validation Acc: 0.800000 	Validation Loss: 0.037445
# Epoch: 9 	Training Acc: 0.956250 	Training Loss: 0.003797 	Validation Acc: 1.000000 	Validation Loss: 0.028316
# Epoch: 10 	Training Acc: 0.937500 	Training Loss: 0.003910 	Validation Acc: 1.000000 	Validation Loss: 0.028063
# Validation loss decreased (0.028107 --> 0.028063).  Saving model ...
# Epoch: 11 	Training Acc: 0.975000 	Training Loss: 0.003663 	Validation Acc: 0.900000 	Validation Loss: 0.032149
# Epoch: 12 	Training Acc: 0.981250 	Training Loss: 0.003638 	Validation Acc: 0.850000 	Validation Loss: 0.035984
# Epoch: 13 	Training Acc: 0.975000 	Training Loss: 0.003625 	Validation Acc: 0.850000 	Validation Loss: 0.033923
# Epoch: 14 	Training Acc: 0.981250 	Training Loss: 0.003643 	Validation Acc: 1.000000 	Validation Loss: 0.028134
# Epoch: 15 	Training Acc: 0.925000 	Training Loss: 0.003937 	Validation Acc: 0.900000 	Validation Loss: 0.033470
# Epoch: 16 	Training Acc: 0.937500 	Training Loss: 0.003899 	Validation Acc: 0.950000 	Validation Loss: 0.031359
# Epoch: 17 	Training Acc: 0.950000 	Training Loss: 0.003766 	Validation Acc: 1.000000 	Validation Loss: 0.027910
# Validation loss decreased (0.028063 --> 0.027910).  Saving model ...
# Epoch: 18 	Training Acc: 0.975000 	Training Loss: 0.003598 	Validation Acc: 0.800000 	Validation Loss: 0.036657
# Epoch: 19 	Training Acc: 0.968750 	Training Loss: 0.003644 	Validation Acc: 0.850000 	Validation Loss: 0.032909
# Epoch: 20 	Training Acc: 0.925000 	Training Loss: 0.003937 	Validation Acc: 0.850000 	Validation Loss: 0.034909
# Epoch: 21 	Training Acc: 0.962500 	Training Loss: 0.003673 	Validation Acc: 0.800000 	Validation Loss: 0.037534
# Epoch: 22 	Training Acc: 0.962500 	Training Loss: 0.003692 	Validation Acc: 0.900000 	Validation Loss: 0.033134
# Epoch: 23 	Training Acc: 0.975000 	Training Loss: 0.003618 	Validation Acc: 0.900000 	Validation Loss: 0.032286
# Epoch: 24 	Training Acc: 0.950000 	Training Loss: 0.003720 	Validation Acc: 0.900000 	Validation Loss: 0.032270
# Epoch: 25 	Training Acc: 0.968750 	Training Loss: 0.003652 	Validation Acc: 0.950000 	Validation Loss: 0.030349
# Epoch: 26 	Training Acc: 0.975000 	Training Loss: 0.003596 	Validation Acc: 1.000000 	Validation Loss: 0.029079
# Epoch: 27 	Training Acc: 0.918750 	Training Loss: 0.003893 	Validation Acc: 0.600000 	Validation Loss: 0.047896
# Epoch: 28 	Training Acc: 0.937500 	Training Loss: 0.003851 	Validation Acc: 0.950000 	Validation Loss: 0.030310
# Epoch: 29 	Training Acc: 0.956250 	Training Loss: 0.003718 	Validation Acc: 0.950000 	Validation Loss: 0.030242
# Epoch: 30 	Training Acc: 0.968750 	Training Loss: 0.003697 	Validation Acc: 0.900000 	Validation Loss: 0.034007
# Epoch: 31 	Training Acc: 0.968750 	Training Loss: 0.003630 	Validation Acc: 1.000000 	Validation Loss: 0.028624
# Epoch: 32 	Training Acc: 0.987500 	Training Loss: 0.003561 	Validation Acc: 0.950000 	Validation Loss: 0.030102
# Epoch: 33 	Training Acc: 0.962500 	Training Loss: 0.003689 	Validation Acc: 0.950000 	Validation Loss: 0.029913
# Epoch: 34 	Training Acc: 0.962500 	Training Loss: 0.003716 	Validation Acc: 0.900000 	Validation Loss: 0.031459
# Epoch: 35 	Training Acc: 0.968750 	Training Loss: 0.003656 	Validation Acc: 1.000000 	Validation Loss: 0.027694
# Validation loss decreased (0.027910 --> 0.027694).  Saving model ...
# Epoch: 36 	Training Acc: 0.943750 	Training Loss: 0.003804 	Validation Acc: 0.900000 	Validation Loss: 0.032599
# Epoch: 37 	Training Acc: 0.950000 	Training Loss: 0.003721 	Validation Acc: 1.000000 	Validation Loss: 0.028130
# Epoch: 38 	Training Acc: 0.956250 	Training Loss: 0.003656 	Validation Acc: 1.000000 	Validation Loss: 0.027623
# Validation loss decreased (0.027694 --> 0.027623).  Saving model ...
# Epoch: 39 	Training Acc: 0.956250 	Training Loss: 0.003722 	Validation Acc: 0.950000 	Validation Loss: 0.030335
# Epoch: 40 	Training Acc: 0.975000 	Training Loss: 0.003586 	Validation Acc: 0.950000 	Validation Loss: 0.029510
# Epoch: 41 	Training Acc: 0.968750 	Training Loss: 0.003641 	Validation Acc: 1.000000 	Validation Loss: 0.027605
# Validation loss decreased (0.027623 --> 0.027605).  Saving model ...
# Epoch: 42 	Training Acc: 0.943750 	Training Loss: 0.003797 	Validation Acc: 1.000000 	Validation Loss: 0.027574
# Validation loss decreased (0.027605 --> 0.027574).  Saving model ...
# Epoch: 43 	Training Acc: 0.968750 	Training Loss: 0.003675 	Validation Acc: 1.000000 	Validation Loss: 0.028109
# Epoch: 44 	Training Acc: 0.962500 	Training Loss: 0.003677 	Validation Acc: 0.900000 	Validation Loss: 0.032669
# Epoch: 45 	Training Acc: 0.981250 	Training Loss: 0.003577 	Validation Acc: 1.000000 	Validation Loss: 0.028214
# Epoch: 46 	Training Acc: 0.975000 	Training Loss: 0.003609 	Validation Acc: 0.950000 	Validation Loss: 0.031351
# Epoch: 47 	Training Acc: 0.931250 	Training Loss: 0.003818 	Validation Acc: 1.000000 	Validation Loss: 0.027626
# Epoch: 48 	Training Acc: 0.931250 	Training Loss: 0.003840 	Validation Acc: 0.900000 	Validation Loss: 0.032129
# Epoch: 49 	Training Acc: 0.962500 	Training Loss: 0.003667 	Validation Acc: 0.950000 	Validation Loss: 0.031491
# Epoch: 50 	Training Acc: 0.962500 	Training Loss: 0.003674 	Validation Acc: 0.900000 	Validation Loss: 0.032944
# Epoch: 51 	Training Acc: 0.962500 	Training Loss: 0.003643 	Validation Acc: 1.000000 	Validation Loss: 0.028283
# Epoch: 52 	Training Acc: 0.962500 	Training Loss: 0.003685 	Validation Acc: 0.950000 	Validation Loss: 0.029994
# Epoch: 53 	Training Acc: 0.975000 	Training Loss: 0.003595 	Validation Acc: 0.950000 	Validation Loss: 0.028731
# Epoch: 54 	Training Acc: 0.981250 	Training Loss: 0.003604 	Validation Acc: 0.950000 	Validation Loss: 0.029879
# Epoch: 55 	Training Acc: 0.987500 	Training Loss: 0.003539 	Validation Acc: 0.850000 	Validation Loss: 0.034758
# Epoch: 56 	Training Acc: 0.962500 	Training Loss: 0.003656 	Validation Acc: 0.950000 	Validation Loss: 0.029767
# Epoch: 57 	Training Acc: 0.968750 	Training Loss: 0.003660 	Validation Acc: 0.950000 	Validation Loss: 0.030472
# Epoch: 58 	Training Acc: 0.987500 	Training Loss: 0.003583 	Validation Acc: 1.000000 	Validation Loss: 0.027588
# Epoch: 59 	Training Acc: 0.975000 	Training Loss: 0.003614 	Validation Acc: 0.950000 	Validation Loss: 0.030212
# Epoch: 60 	Training Acc: 0.950000 	Training Loss: 0.003721 	Validation Acc: 0.800000 	Validation Loss: 0.037608
# Epoch: 61 	Training Acc: 0.950000 	Training Loss: 0.003830 	Validation Acc: 0.900000 	Validation Loss: 0.033049
# Epoch: 62 	Training Acc: 0.968750 	Training Loss: 0.003634 	Validation Acc: 1.000000 	Validation Loss: 0.027655
# Epoch: 63 	Training Acc: 0.981250 	Training Loss: 0.003582 	Validation Acc: 1.000000 	Validation Loss: 0.027885
# Epoch: 64 	Training Acc: 0.937500 	Training Loss: 0.003828 	Validation Acc: 0.950000 	Validation Loss: 0.031677
# Epoch: 65 	Training Acc: 0.968750 	Training Loss: 0.003647 	Validation Acc: 1.000000 	Validation Loss: 0.027577
# Epoch: 66 	Training Acc: 0.968750 	Training Loss: 0.003647 	Validation Acc: 1.000000 	Validation Loss: 0.028238
# Epoch: 67 	Training Acc: 0.968750 	Training Loss: 0.003654 	Validation Acc: 1.000000 	Validation Loss: 0.027646
# Epoch: 68 	Training Acc: 0.968750 	Training Loss: 0.003642 	Validation Acc: 0.900000 	Validation Loss: 0.033081
# Epoch: 69 	Training Acc: 0.981250 	Training Loss: 0.003577 	Validation Acc: 0.900000 	Validation Loss: 0.031480
# Epoch: 70 	Training Acc: 0.962500 	Training Loss: 0.003700 	Validation Acc: 1.000000 	Validation Loss: 0.027869
# Epoch: 71 	Training Acc: 0.975000 	Training Loss: 0.003604 	Validation Acc: 1.000000 	Validation Loss: 0.027573
# Validation loss decreased (0.027574 --> 0.027573).  Saving model ...
# Epoch: 72 	Training Acc: 0.900000 	Training Loss: 0.004041 	Validation Acc: 1.000000 	Validation Loss: 0.027574
# Epoch: 73 	Training Acc: 0.962500 	Training Loss: 0.003686 	Validation Acc: 0.900000 	Validation Loss: 0.031732
# Epoch: 74 	Training Acc: 0.956250 	Training Loss: 0.003694 	Validation Acc: 1.000000 	Validation Loss: 0.027857
# Epoch: 75 	Training Acc: 0.981250 	Training Loss: 0.003581 	Validation Acc: 0.950000 	Validation Loss: 0.029849
# Epoch: 76 	Training Acc: 0.975000 	Training Loss: 0.003601 	Validation Acc: 1.000000 	Validation Loss: 0.027670
# Epoch: 77 	Training Acc: 0.981250 	Training Loss: 0.003574 	Validation Acc: 0.950000 	Validation Loss: 0.029180
# Epoch: 78 	Training Acc: 0.931250 	Training Loss: 0.003783 	Validation Acc: 1.000000 	Validation Loss: 0.027998
# Epoch: 79 	Training Acc: 0.981250 	Training Loss: 0.003566 	Validation Acc: 0.950000 	Validation Loss: 0.030832
# Epoch: 80 	Training Acc: 0.968750 	Training Loss: 0.003650 	Validation Acc: 0.950000 	Validation Loss: 0.030099
# Epoch: 81 	Training Acc: 0.956250 	Training Loss: 0.003737 	Validation Acc: 0.850000 	Validation Loss: 0.032667
# Epoch: 82 	Training Acc: 0.975000 	Training Loss: 0.003597 	Validation Acc: 0.950000 	Validation Loss: 0.031417
# Epoch: 83 	Training Acc: 0.968750 	Training Loss: 0.003625 	Validation Acc: 0.950000 	Validation Loss: 0.030402
# Epoch: 84 	Training Acc: 0.968750 	Training Loss: 0.003666 	Validation Acc: 0.900000 	Validation Loss: 0.032867
# Epoch: 85 	Training Acc: 0.987500 	Training Loss: 0.003539 	Validation Acc: 1.000000 	Validation Loss: 0.027805
# Epoch: 86 	Training Acc: 0.956250 	Training Loss: 0.003706 	Validation Acc: 1.000000 	Validation Loss: 0.027943
# Epoch: 87 	Training Acc: 0.968750 	Training Loss: 0.003637 	Validation Acc: 0.950000 	Validation Loss: 0.028682
# Epoch: 88 	Training Acc: 0.962500 	Training Loss: 0.003667 	Validation Acc: 1.000000 	Validation Loss: 0.027573
# Epoch: 89 	Training Acc: 0.956250 	Training Loss: 0.003693 	Validation Acc: 0.900000 	Validation Loss: 0.032601
# Epoch: 90 	Training Acc: 0.943750 	Training Loss: 0.003800 	Validation Acc: 1.000000 	Validation Loss: 0.027580
# Epoch: 91 	Training Acc: 0.950000 	Training Loss: 0.003745 	Validation Acc: 1.000000 	Validation Loss: 0.027606
# Epoch: 92 	Training Acc: 0.981250 	Training Loss: 0.003586 	Validation Acc: 0.900000 	Validation Loss: 0.033335
# Epoch: 93 	Training Acc: 0.956250 	Training Loss: 0.003717 	Validation Acc: 1.000000 	Validation Loss: 0.027574
# Epoch: 94 	Training Acc: 0.981250 	Training Loss: 0.003562 	Validation Acc: 0.900000 	Validation Loss: 0.032595
# Epoch: 95 	Training Acc: 0.975000 	Training Loss: 0.003622 	Validation Acc: 0.850000 	Validation Loss: 0.033777
# Epoch: 96 	Training Acc: 0.987500 	Training Loss: 0.003530 	Validation Acc: 0.900000 	Validation Loss: 0.031343
# Epoch: 97 	Training Acc: 0.993750 	Training Loss: 0.003508 	Validation Acc: 0.900000 	Validation Loss: 0.032546
# Epoch: 98 	Training Acc: 0.987500 	Training Loss: 0.003526 	Validation Acc: 1.000000 	Validation Loss: 0.027773
# Epoch: 99 	Training Acc: 0.993750 	Training Loss: 0.003508 	Validation Acc: 1.000000 	Validation Loss: 0.028030
# Epoch: 100 	Training Acc: 0.975000 	Training Loss: 0.003619 	Validation Acc: 1.000000 	Validation Loss: 0.027984

# %%
plt.style.use("ggplot")
plt.figure()
loss_lis = [tensor.item() for tensor in train_loss_list]
plt.plot(loss_lis, label="train_loss")
plt.title("Train-Loss")
plt.xlabel("Epoch #")
plt.ylabel("Loss")
plt.legend(loc="lower left")

# %%
plt.style.use("ggplot")
plt.figure()

print()
train_acc_lis = [tensor.item() for tensor in train_accuracy_list]
valid_acc_lis = [tensor.item() for tensor in valid_accuracy_list]

plt.plot(train_acc_lis, label="train_acc")
plt.plot(valid_acc_lis, label="valid_acc")

plt.title("Accuracy")
plt.xlabel("Epoch #")
plt.ylabel("Accuracy")
plt.legend(loc="lower left")

# %%
torch.save(model, 'E:/Smoke/model_transfer.pt')

# %%
from PIL import Image

class_names = class_names = ['Fire', 'Smoke']

def predict(image):
    prediction_transform = transforms.Compose([transforms.Resize(size=(224, 224)),
                                     transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])])

    image = prediction_transform(image)[:3,:,:].unsqueeze(0)
    image = image.cuda()

    pred = model(image)
    idx = torch.argmax(pred)
    prob = pred[0][idx].item()*100
    
    return class_names[idx], prob

# %%
def test(path):
    img = Image.open(path)
    plt.imshow(img)
    plt.show()

    prediction, prob = predict(img)
    print(prediction, prob)
    

# for img_file in os.listdir('E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Test/Test'):
#     print(img_file, "IMG FILE")
#     img_path = os.path.join('E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Test/Test/', img_file)
#     app(img_path)
    
test("E:/Smoke/smoke1.jpg")
test("E:/Smoke/Datacluster Fire and Smoke Sample (84).jpg")
test("E:/Smoke/Dataset_100/Datacluster_Fire_and_Smoke_Sample/Others/download (15).jpg")
# Out:
# Smoke 94.76183652877808
# c:\Users\XYMA_HPC\anaconda3\envs\torch\lib\site-packages\torch\nn\modules\container.py:217: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   input = module(input)
# Fire 100.0
# Smoke 100.0
